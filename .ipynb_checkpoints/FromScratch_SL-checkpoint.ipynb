# %% [markdown]
# <a href="https://colab.research.google.com/github/Lor3nzoVis3/DeepLearning_ProjectLV_GB/blob/master/FromScratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
@authors: LorenzoVisentini and Gianmarco Bolcato
"""

modelName = "FromScratch"


#import
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#keras
# import keras
from keras.layers import Dense, Dropout, Flatten, Conv2D
from keras.layers import BatchNormalization, MaxPooling2D, Dropout, AveragePooling2D
from keras.models import Model, Sequential
from keras import optimizers
from keras.preprocessing.image  import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %%
# link with Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# %%
#Images parameters
img_width = 178 
img_height = 218
img_target_size = (img_height, img_width)
shape = (img_height, img_width, 3)

# Source Light
# Jupyter notebook paths
train_dir = './source_light/train'
val_dir = './source_light/val' 
test_dir = './source_light/test' 

# Google Colab paths
# train_dir = '/content/drive/My Drive/Deep Learning Project - Image Classification/source_light/train'
# val_dir = '/content/drive/My Drive/Deep Learning Project - Image Classification/source_light/val' 
# test_dir = '/content/drive/My Drive/Deep Learning Project - Image Classification/source_light/test'

# %%
n_classes = 3

# Hyperparameters
batch_size = 32
epochs = 10
conv_depth = 8
drop_rate = 0.8
lr = 0.001

# %%
#model
model = Sequential()

model.add(Conv2D(conv_depth, kernel_size = (3,3), activation= 'relu', input_shape = shape))
model.add(Conv2D(conv_depth, kernel_size = (3,3), activation= 'relu'))
model.add(BatchNormalization())
model.add(AveragePooling2D(pool_size=(2,2)))
model.add(Dropout(drop_rate//3))
# model.add(Dropout(drop_rate))

model.add(Conv2D(conv_depth, kernel_size = (3,3), activation= 'relu'))
model.add(Conv2D(conv_depth, kernel_size = (3,3), activation= 'relu'))
model.add(BatchNormalization())
model.add(AveragePooling2D(pool_size=(2,2)))
model.add(Dropout(drop_rate//3))
# model.add(Dropout(drop_rate))

model.add(Conv2D(conv_depth*2, kernel_size = (3,3), activation= 'relu'))
model.add(Conv2D(conv_depth*2, kernel_size = (3,3), activation= 'relu'))
model.add(BatchNormalization())
model.add(AveragePooling2D(pool_size=(2,2)))
model.add(Dropout(drop_rate//3))
# model.add(Dropout(drop_rate))

model.add(Conv2D(conv_depth*2, kernel_size = (3,3), activation= 'relu'))
model.add(Conv2D(conv_depth*2, kernel_size = (3,3), activation= 'relu'))
model.add(BatchNormalization())
model.add(AveragePooling2D(pool_size=(2,2)))
model.add(Dropout(drop_rate//3))
# # model.add(Dropout(drop_rate))


model.add(Flatten())
model.add(Dense(512, activation= 'relu'))
model.add(BatchNormalization())
model.add(Dropout(drop_rate))
model.add(Dense(n_classes, activation= 'softmax'))

# custom optimizer
opt = optimizers.Adam(learning_rate=lr)

model.compile(optimizer = opt,
              loss = 'categorical_crossentropy',  #because we have 3 possible outputs
              metrics = ['accuracy'])
# Out:
# WARNING:tensorflow:Large dropout rate: 0.8 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.

# %%
# preprocessing
# https://machinelearningmastery.com/how-to-configure-image-data-augmentation-when-training-deep-learning-neural-networks/
# https://www.pyimagesearch.com/2019/07/08/keras-imagedatagenerator-and-data-augmentation/

# train_gen = ImageDataGenerator(width_shift_range=[0,0.25],
#                             height_shift_range=[0,0.25],
#                             zoom_range=[0.75,1.0],
#                             fill_mode="nearest")
train_gen = ImageDataGenerator()

# Set aug variable to save if the model used data augmentation or not
aug = True
if aug == True:
    modelName = modelName+'Aug'

test_gen = ImageDataGenerator()

train_generator = train_gen.flow_from_directory(directory=train_dir,
                                                    target_size=img_target_size,
                                                    color_mode="rgb",
                                                    batch_size=batch_size,
                                                    class_mode="categorical",
                                                    shuffle=True,
                                                    seed=42
                                                    )

val_generator = test_gen.flow_from_directory(directory=val_dir,
                                                    target_size=img_target_size,
                                                    color_mode="rgb",
                                                    batch_size=batch_size,
                                                    class_mode="categorical",
                                                    shuffle=True,
                                                    seed=42
                                                    )

test_generator = test_gen.flow_from_directory(directory = test_dir,
                                                    target_size = img_target_size,
                                                    color_mode="rgb",
                                                    batch_size = batch_size,
                                                    class_mode = "categorical",
                                                    shuffle=True,
                                                    seed=42
                                                )
# Out:
# Found 6999 images belonging to 3 classes.
# Found 1500 images belonging to 3 classes.
# Found 1501 images belonging to 3 classes.

# %%
history = model.fit_generator(generator = train_generator,
                             steps_per_epoch = train_generator.n//batch_size,
                             epochs = epochs,
                             validation_data = val_generator,
                             validation_steps=val_generator.n//batch_size
                             )
# Out:
# Epoch 1/10
# 218/218 [==============================] - 13s 59ms/step - loss: 1.1323 - accuracy: 0.7019 - val_loss: 0.6349 - val_accuracy: 0.6726
# Epoch 2/10
# 218/218 [==============================] - 10s 45ms/step - loss: 0.5501 - accuracy: 0.8282 - val_loss: 0.2375 - val_accuracy: 0.8733
# Epoch 3/10
# 218/218 [==============================] - 10s 45ms/step - loss: 0.4085 - accuracy: 0.8608 - val_loss: 0.7025 - val_accuracy: 0.8610
# Epoch 4/10
# 218/218 [==============================] - 10s 45ms/step - loss: 0.3375 - accuracy: 0.8804 - val_loss: 0.3295 - val_accuracy: 0.9114
# Epoch 5/10
# 218/218 [==============================] - 10s 45ms/step - loss: 0.3356 - accuracy: 0.8812 - val_loss: 0.1079 - val_accuracy: 0.9189
# Epoch 6/10
# 218/218 [==============================] - 10s 45ms/step - loss: 0.2777 - accuracy: 0.8992 - val_loss: 0.0825 - val_accuracy: 0.9053
# Epoch 7/10
# 218/218 [==============================] - 10s 45ms/step - loss: 0.2804 - accuracy: 0.8978 - val_loss: 0.1590 - val_accuracy: 0.9067
# Epoch 8/10
# 218/218 [==============================] - 10s 45ms/step - loss: 0.2611 - accuracy: 0.9054 - val_loss: 0.4838 - val_accuracy: 0.7807
# Epoch 9/10
# 218/218 [==============================] - 10s 47ms/step - loss: 0.2441 - accuracy: 0.9107 - val_loss: 0.3766 - val_accuracy: 0.8822
# Epoch 10/10
# 218/218 [==============================] - 10s 46ms/step - loss: 0.2442 - accuracy: 0.9081 - val_loss: 0.2525 - val_accuracy: 0.9053

# %%
# consider highlight the different values of hyperparameters used
# OR orient o SL source light, Bs batch size, Ep epochs, Dr drop rate, Lr learning rate
# CHECK ALWAYS BOOLEAN PATCH VALUES (on top)

# create models folder if doesn't exist
path_models = './Models'
if os.path.exists(path_models) == False:
    os.makedirs(path_models)
else: 
    print('Folder Models already exists')
    
# save model and history
# file_model = '/content/drive/My Drive/Deep Learning Project - Image Classification/Models/'+ modelName + 'SL' + '_Bs' + str(batch_size) + '_Ep' + str(epochs) + '_Dr' + str(drop_rate) + '_Lr' + str(lr)
file_model = './Models/'+ modelName + 'SL' + '_Bs' + str(batch_size) + '_Ep' + str(epochs) + '_Dr' + str(drop_rate) + '_ConvD' + str(conv_depth) +'_Lr' + str(lr)
model.save(file_model + '.h5')
print(file_model)

#save history
# create models folder if doesn't exist
path_history = './History'
if os.path.exists(path_history) == False:
    os.makedirs(path_history)
else: 
    print('Folder History already exists')
file_hist = file_model + '.csv'
df_history = pd.DataFrame(history.history)
with open(file_hist, 'w') as file:
    df_history.to_csv(file)
print(file_hist)
# Out:
# Folder Models already exists
# ./Models/FromScratchAugSL_Bs32_Ep10_Dr0.8_ConvD8_Lr0.001
# Folder History already exists
# ./Models/FromScratchAugSL_Bs32_Ep10_Dr0.8_ConvD8_Lr0.001.csv

# %%
#plot results
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
#evaluation
# https://stackoverflow.com/questions/40564936/keras-what-is-the-difference-between-model-evaluate-generator-and-model-predict
steps = test_generator.n // test_generator.batch_size

accuracy_ontest = model.evaluate_generator(test_generator, steps)
predictions_ontest = model.predict_generator(test_generator, steps)
print(accuracy_ontest)
print(predictions_ontest)
# Out:
# [0.31160402297973633, 0.8885869383811951]
# [[8.89951706e-01 1.04929954e-01 5.11833467e-03]
#  [6.47203445e-01 1.79491079e-04 3.52617085e-01]
#  [7.52668321e-01 1.10287100e-01 1.37044623e-01]
#  ...
#  [9.90750611e-01 4.83104913e-03 4.41836100e-03]
#  [9.94409859e-01 3.37138190e-03 2.21872656e-03]
#  [9.75911319e-01 5.70430327e-03 1.83844045e-02]]

# %%
# Load image
from os import listdir, path
import cv2
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array

import random

import matplotlib.image as mpimg

samples_dir = './img_align_celeba_1000samples'

listOfFiles = [os.path.join(samples_dir,file) for file in os.listdir(samples_dir)  if os.path.isfile(os.path.join(samples_dir, file))]
print(len(listOfFiles))
random.shuffle(listOfFiles)

# Output some predictions
# print 9 predictions (sample)
n_files = 9
imageShape=(218,178)
i = 1

fig, ax = plt.subplots(figsize=(10,10))

labels = ['center', 'left', 'right']

for image in listOfFiles[0:n_files]:
    ax.set_axis_off()
    
    img = load_img(image, target_size=(218, 178))
    # convert to array
    img = img_to_array(img)
    # reshape into a single sample with 3 channels
    img = img.reshape(1, 218, 178, 3)
    # center pixel data
#   img = img.astype('float32')
    
    pred = model.predict(img)
    idx_label = np.argmax(pred[0])
    pred_labels = labels[idx_label]
    
    img = mpimg.imread(image)
    ax = fig.add_subplot(3,3,i)
    ax.imshow(img)      
    ax.set_title('{} - {:03.1f}%'.format(labels[idx_label],pred[0][idx_label]*100))
    
    i += 1
# Out:
# 1000

# %%
print(predictions_ontest)
pred=[]
label=[]
for i in range(len(predictions_ontest)):
    idx = np.argmax(predictions_ontest[i])
    pred.append(predictions_ontest[i][idx])
    label.append(labels[idx])
pred_to_print = np.vstack((label, pred)).T
# Save scores in a csv file
pred_to_save = pd.DataFrame(pred_to_print, columns=['predictions', 'labels']).to_csv('predictions.csv', sep=';')
